# %% [markdown]
# Import Libraries

# %%
import json
from datetime import datetime
import pandas as pd
import os

# %% [markdown]
# Parameters

# %%
# JSON 파일 디렉토리 경로
json_dir = "DB/proposal/json"

# 파일명 패턴: proposal_YYYYMMDD_HHMM.json
def extract_datetime_from_filename(filename):
    try:
        # "proposal_20250606_1414.json" → datetime object
        base = filename.replace("삼성전자_proposal_v1", "").replace(".json", "")
        return datetime.strptime(base, "%Y%m%d_%H%M")
    except:
        return None

# JSON 파일 목록 중 최신 파일 서치
json_files = [
    f for f in os.listdir(json_dir)
    if f.startswith("삼성전자_proposal_v1") and f.endswith(".json")
]

if not json_files:
    raise FileNotFoundError("❌ proposal JSON 파일이 존재하지 않습니다.")

# 최신 파일 선택
latest_file = max(json_files, key=lambda f: extract_datetime_from_filename(f))
latest_path = os.path.join(json_dir, latest_file)

# 파일 읽어서 dictionary로 변환
with open(latest_path, "r", encoding="utf-8") as f:
    proposal_dict = json.load(f)

print(f"✅ 최신 파일 로드 완료: {latest_file}")
# Out:
# ✅ 최신 파일 로드 완료: 삼성전자_proposal_v120250719_2304.json

# %%
# 데이터프레임으로 변환
rows = []
for slide_id, slide_data in proposal_dict.items():
    research_results = slide_data.get("research_results", {})
    for question, result in research_results.items():
        rows.append({
            "slide_id": slide_id,
            "research_question": question,
            "research_summary": result.get("content", ""),
            "urls": result.get("urls", [])
        })

df = pd.DataFrame(rows)
# 오늘 날짜를 YYYYMMDD 형식으로 지정
today_str = datetime.today().strftime('%Y%m%d')

# 저장 경로 설정
save_dir = 'DB/proposal/삼성전자_research_results'
os.makedirs(save_dir, exist_ok=True)
save_path = os.path.join(save_dir, f'research_results_{today_str}.xlsx')

# 엑셀로 저장
df.to_excel(save_path, index=False)

# %% [markdown]
# Genspark에 전달하기 위한 data preprocessing

# %%
def clean_slide(slide):
    # 특정 키 제거
    slide.pop("needs_research", None)
    slide.pop("research_results", None)
    
    # elements 안쪽에 urls 있을 수 있으므로 탐색
    if "elements" in slide:
        for key, value in slide["elements"].items():
            if isinstance(value, dict) and "urls" in value:
                value.pop("urls", None)
    return slide

# 모든 슬라이드에 대해 정리
for slide_id in proposal_dict:
    proposal_dict[slide_id] = clean_slide(proposal_dict[slide_id])

# %%
proposal_dict
# Out:
# {'cover_page': {'elements': {'Title': '삼성전자 MX 미국 직영 매장 PMO 프로젝트',
#    'Subtitle': 'EY 컨설팅',
#    'ProjectDate': '2025년 6월 25일',
#    'PreparedBy': 'EY 컨설팅',
#    'Logo': '삼성전자 로고'}},
#  'table_of_contents': {'slide_description': '전체 제안서의 슬라이드 구성을 한눈에 파악할 수 있도록 시각적으로 정리합니다.',
#   'description': '',
#   'elements': {'Title': '목차',
#    'SectionList': ['Executive Summary',
#     'Project Understanding',
#     'Client Needs Summary',
#     'Requirement Details',
#     'Market Analysis & Trends',
#     'Strategic Recommendations',
#     'Implementation Plan',
#     'Risk Management Plan',
#     'Expected Benefits',
#     'Investment & Budget Estimation',
#     'Team Introduction',
#     'Why Us & Differentiation',
#     'Closing Summary',
#     'Q&A',
#     'Appendix']}},
#  'executive_summary': {'slide_description': '제안서 전체의 핵심 내용을 1~2페이지 내에 요약하여 임원 또는 의사결정자가 빠르게 이해할 수 있도록 구성합니다.',
#   'description': '삼성전자의 미국 직영 매장 구축 및 운영을 위한 PMO 프로젝트는 새로운 리테일 사업 분야에서의 성공적인 진입을 목표로 합니다. EY 컨설팅은 선진 사례와 트렌드를 기반으로 한 맞춤형 전략을 통해 삼성전자가 직영 매장 운영의 모든 영역에서 경쟁력을 갖출 수 있도록 지원할 것입니다.',
#   'elements': {'Title': 'Executive Summary',
#    'MiddleText': '삼성전자의 리테일 혁신을 위한 맞춤형 PMO 솔루션',
#    'SummaryPoints': ['선진사 및 트렌드 기반의 직영 매장 운영 필수 영역 제안',
#     '글로벌 직영 매장 구축/운영 가이드라인 Framework 제공',
#     '프로젝트 관리 방안 및 문서 Tool 제안'],
#    'ClientValuePoints': ['삼성전자의 리테일 시장 진입 가속화',
#     '운영 효율성 및 고객 경험 개선',
#     '글로벌 표준화된 운영 모델 확보'],
#    'QuoteBox': '삼성전자의 리테일 혁신을 위한 전략적 파트너, EY 컨설팅',
#    'MetricsOverview': '계약 기간: 2025년 7월 ~ 2025년 10월'}},
#  'project_understanding': {'slide_description': '프로젝트의 필요성과 배경을 설명하며, 고객의 상황과 과제를 명확히 인식하고 있다는 점을 전달합니다.',
#   'description': '삼성전자는 제조업에서 리테일로의 확장을 통해 새로운 시장 기회를 모색하고 있습니다. 직영 매장 운영은 삼성전자의 브랜드 가치를 직접적으로 고객에게 전달할 수 있는 중요한 채널로, 성공적인 운영 모델 확보가 필수적입니다. 이를 위해 EY 컨설팅은 삼성전자의 내부 역량 배양과 성공 모델 발굴을 지원할 것입니다.',
#   'elements': {'Title': '프로젝트 배경 및 필요성',
#    'MiddleText': '리테일 시장에서의 성공적 진입을 위한 전략적 필요성',
#    'KeyObjectives': ['직영 매장 운영 모델 확보', '내부 역량 배양 및 성공 모델 발굴'],
#    'BackgroundIssues': ['제조업과 다른 리테일 사업의 특성', '신규 사업 분야로의 진입'],
#    'StrategicImplications': ['브랜드 가치 강화', '고객 경험 개선']}},
#  'client_needs_summary': {'slide_description': '고객의 구체적인 요구사항을 명확하게 정리해 실무적 방향성과 대응의 기준을 제시합니다.',
#   'description': '삼성전자는 직영 매장 운영의 성공을 위해 선진사 사례 분석과 트렌드 기반의 필수 영역 제안을 요구하고 있습니다. 또한, 글로벌 직영 매장 구축/운영 가이드라인과 프로젝트 관리 방안, 운영 비용 및 인력 계획을 포함한 포괄적인 제안이 필요합니다.',
#   'elements': {'Title': '고객 요구사항 요약',
#    'MiddleText': '삼성전자의 리테일 성공을 위한 구체적 요구사항',
#    'NeedsBulletPoints': ['선진사 및 트렌드 기반의 필수 영역 제안',
#     '글로벌 직영 매장 구축/운영 가이드라인 Framework',
#     '프로젝트 관리 방안 및 문서 Tool',
#     '운영 비용 및 인력 운영 계획'],
#    'StrategicDrivers': ['리테일 시장 진입 전략', '글로벌 표준화'],
#    'NeedsMatrix': {'description': '요구사항 정리',
#     'table': [['요구사항', '비즈니스적 영향', '구현 난이도'],
#      ['필수 영역 제안', '운영 효율성 향상', '중'],
#      ['가이드라인 Framework', '글로벌 표준화', '상'],
#      ['프로젝트 관리 방안', '프로젝트 성공률 증가', '중'],
#      ['운영 비용 계획', '비용 효율성', '하']]},
#    'ImplicationColumn': '각 요구에 따른 비즈니스적 영향 또는 구현 난이도',
#    'RFPQuoteHighlights': '운영 효율성을 20% 이상 개선해야 함'}},
#  'requirement_detail_01': {'slide_description': '프로젝트 또는 제안의 성공을 위해 반드시 충족되어야 할 요구사항(client_needs_summary의 NeedsBulletPoints)을 각 항목별로 명확하게 설명하고 제안하는 슬라이드입니다',
#   'description': '삼성전자의 직영 매장 운영을 위한 필수 영역은 선진사 사례와 최신 트렌드를 반영하여 제안되어야 합니다. 이는 운영 효율성을 높이고 고객 경험을 극대화하는 데 필수적입니다.',
#   'elements': {'Title': '필수 영역 제안',
#    'MiddleText': '선진사 및 트렌드 기반의 필수 영역 제안',
#    'RequirementDescription': '직영 매장 운영의 필수 영역을 선진사 사례와 트렌드를 기반으로 제안합니다.',
#    'ResponsePlanBox': 'EY 컨설팅은 글로벌 리테일 선진사들의 운영 모델을 분석하여 삼성전자에 최적화된 운영 영역을 제안할 것입니다. 이를 통해 운영 효율성을 극대화하고 고객 경험을 향상시킬 수 있습니다.',
#    'AcceptanceCriteria': '제안된 영역이 실제 운영에 적용되어 운영 효율성이 20% 이상 개선됨',
#    'CategoryTag': '비즈니스',
#    'DependencyNote': '글로벌 가이드라인 Framework와 연계 필요',
#    'SolutionApproachDiagram': '3단계 접근: 분석 → 제안 → 실행',
#    'KeyTasksAndDeliverables': '운영 영역 분석 보고서, 제안서',
#    'EffortEstimationBox': '4주, 분석가 2명',
#    'RiskAndMitigationBox': '선진사 사례의 적합성 부족 시, 추가 분석 및 조정',
#    'ToolOrTechnologyUsed': 'Tableau, Power BI',
#    'StepByStepActionPlan': '1. 선진사 사례 분석 → 2. 트렌드 반영 → 3. 제안서 작성'}},
#  'requirement_detail_02': {'slide_description': '프로젝트 또는 제안의 성공을 위해 반드시 충족되어야 할 요구사항(client_needs_summary의 NeedsBulletPoints)을 각 항목별로 명확하게 설명하고 제안하는 슬라이드입니다',
#   'description': '글로벌 직영 매장 구축/운영 가이드라인은 삼성전자의 글로벌 확장 전략을 지원하며, 일관된 브랜드 경험을 제공하기 위해 필수적입니다.',
#   'elements': {'Title': '글로벌 가이드라인 Framework',
#    'MiddleText': '글로벌 직영 매장 구축/운영 가이드라인 Framework',
#    'RequirementDescription': '글로벌 직영 매장 운영의 일관성을 위해 가이드라인 Framework를 제안합니다.',
#    'ResponsePlanBox': 'EY 컨설팅은 글로벌 시장에서의 성공 사례를 분석하여 삼성전자에 맞는 운영 가이드라인을 개발할 것입니다. 이는 글로벌 확장 시 일관된 브랜드 경험을 제공하는 데 기여할 것입니다.',
#    'AcceptanceCriteria': '가이드라인이 글로벌 매장에 적용되어 일관된 운영이 이루어짐',
#    'CategoryTag': '비즈니스',
#    'DependencyNote': '필수 영역 제안과 연계 필요',
#    'SolutionApproachDiagram': '5단계 접근: 조사 → 분석 → 개발 → 검토 → 배포',
#    'KeyTasksAndDeliverables': '가이드라인 문서, 적용 사례 보고서',
#    'EffortEstimationBox': '6주, 컨설턴트 3명',
#    'RiskAndMitigationBox': '글로벌 시장의 다양성으로 인한 적용 어려움, 지역별 맞춤화 필요',
#    'ToolOrTechnologyUsed': 'Confluence, JIRA',
#    'StepByStepActionPlan': '1. 시장 조사 → 2. 성공 사례 분석 → 3. 가이드라인 개발'}},
#  'requirement_detail_03': {'slide_description': '프로젝트 또는 제안의 성공을 위해 반드시 충족되어야 할 요구사항(client_needs_summary의 NeedsBulletPoints)을 각 항목별로 명확하게 설명하고 제안하는 슬라이드입니다',
#   'description': '프로젝트 관리 방안은 직영 매장 구축 및 운영의 성공적인 실행을 보장하기 위해 필수적입니다. 이는 문서화된 Tool을 통해 체계적으로 관리되어야 합니다.',
#   'elements': {'Title': '프로젝트 관리 방안',
#    'MiddleText': '실행 체계 확립을 위한 프로젝트 관리 방안',
#    'RequirementDescription': '직영 매장 구축 및 운영을 위한 프로젝트 관리 방안을 제안합니다.',
#    'ResponsePlanBox': 'EY 컨설팅은 프로젝트 관리의 체계화를 위해 문서화된 Tool을 활용하여 프로젝트의 모든 단계를 관리할 것입니다. 이는 프로젝트의 성공적인 실행을 보장합니다.',
#    'AcceptanceCriteria': '프로젝트 관리 방안이 적용되어 프로젝트가 일정 내에 완료됨',
#    'CategoryTag': '기술적',
#    'DependencyNote': '운영 비용 및 인력 계획과 연계 필요',
#    'SolutionApproachDiagram': 'Agile 접근: 계획 → 실행 → 검토 → 조정',
#    'KeyTasksAndDeliverables': '프로젝트 관리 계획서, 실행 보고서',
#    'EffortEstimationBox': '4주, PM 1명, 지원 인력 2명',
#    'RiskAndMitigationBox': '프로젝트 일정 지연 시, 추가 자원 투입',
#    'ToolOrTechnologyUsed': 'MS Project, Asana',
#    'StepByStepActionPlan': '1. 계획 수립 → 2. 실행 관리 → 3. 검토 및 조정'}},
#  'requirement_detail_04': {'slide_description': '프로젝트 또는 제안의 성공을 위해 반드시 충족되어야 할 요구사항(client_needs_summary의 NeedsBulletPoints)을 각 항목별로 명확하게 설명하고 제안하는 슬라이드입니다',
#   'description': '운영 비용 및 인력 운영 계획은 직영 매장 운영의 지속 가능성을 보장하기 위해 필수적입니다. 이는 효율적인 자원 배분과 비용 절감을 통해 운영의 성공을 지원합니다.',
#   'elements': {'Title': '운영 비용 및 인력 계획',
#    'MiddleText': '운영 비용 및 M/M (업무/인력 운영 계획)',
#    'RequirementDescription': '직영 매장 운영의 지속 가능성을 위한 운영 비용 및 인력 계획을 제안합니다.',
#    'ResponsePlanBox': 'EY 컨설팅은 운영 비용 절감과 효율적인 인력 배치를 통해 직영 매장의 지속 가능한 운영을 지원할 것입니다. 이는 운영의 성공을 보장합니다.',
#    'AcceptanceCriteria': '운영 비용이 예산 내에서 관리되고, 인력이 효율적으로 배치됨',
#    'CategoryTag': '비즈니스',
#    'DependencyNote': '프로젝트 관리 방안과 연계 필요',
#    'SolutionApproachDiagram': '비용 절감 및 인력 최적화 접근',
#    'KeyTasksAndDeliverables': '비용 분석 보고서, 인력 배치 계획서',
#    'EffortEstimationBox': '3주, 재무 분석가 1명, HR 1명',
#    'RiskAndMitigationBox': '비용 초과 시, 추가 절감 방안 모색',
#    'ToolOrTechnologyUsed': 'SAP, Oracle HR',
#    'StepByStepActionPlan': '1. 비용 분석 → 2. 인력 계획 수립 → 3. 실행 및 모니터링'}},
#  'market_analysis_market_overview': {'slide_description': '해당 산업의 크기, 구조, 주요 트렌드를 데이터와 함께 제시해 전체 시장 배경을 설명합니다.',
#   'description': '리테일 산업은 지속적인 성장세를 보이며, 특히 직영 매장 운영은 브랜드 경험을 직접적으로 전달할 수 있는 중요한 채널로 자리 잡고 있습니다. 글로벌 리테일 시장의 주요 트렌드를 분석하여 삼성전자의 직영 매장 운영에 대한 인사이트를 제공합니다.',
#   'elements': {'Title': '리테일 시장 개요 및 트렌드',
#    'MiddleText': '글로벌 리테일 시장의 성장과 직영 매장의 중요성',
#    'GraphLeft': {'description': '리테일 시장 성장률 추이 (2020~2025)',
#     'graph_type': 'Line Chart',
#     'data_source': 'Statista, 2023',
#     'data_table': [['연도', '시장 규모 (억 달러)'],
#      ['2020', '5000'],
#      ['2021', '5500'],
#      ['2022', '6000'],
#      ['2023', '6500'],
#      ['2024', '7000'],
#      ['2025', '7500']]},
#    'TextRight': '리테일 시장은 매년 5% 이상의 성장률을 기록하고 있으며, 직영 매장은 브랜드의 직접적인 고객 경험 제공을 통해 시장 내 경쟁력을 강화할 수 있는 중요한 요소로 부각되고 있습니다.',
#    'MarketSegmentationTable': {'description': '리테일 시장 세분화',
#     'table': [['세그먼트', '비율'],
#      ['직영 매장', '30%'],
#      ['파트너 매장', '40%'],
#      ['온라인', '30%']]},
#    'KeyPlayersBox': '주요 기업: 아마존, 월마트, 애플',
#    'InsightBox': '직영 매장을 통한 브랜드 경험 강화 및 고객 충성도 증가'}},
#  'growth_trend_analysis': {'slide_description': '시장 혹은 기술의 성장세를 데이터 기반으로 시각화하고 그 시사점을 제시합니다.',
#   'description': '직영 매장은 리테일 시장 내에서 빠르게 성장하고 있으며, 이는 브랜드의 직접적인 고객 경험 제공과 운영 효율성 향상에 기여합니다. 이러한 성장세는 삼성전자의 리테일 전략에 중요한 기회로 작용할 것입니다.',
#   'elements': {'Title': '직영 매장 성장 트렌드 분석',
#    'MiddleText': '직영 매장의 빠른 성장과 그 시사점',
#    'GraphLeft': {'description': '직영 매장 성장률 추이 (2020~2025)',
#     'graph_type': 'Bar Chart',
#     'data_source': 'MarketWatch, 2023',
#     'data_table': [['연도', '성장률 (%)'],
#      ['2020', '3'],
#      ['2021', '4'],
#      ['2022', '5'],
#      ['2023', '6'],
#      ['2024', '7'],
#      ['2025', '8']]},
#    'TextRight': '직영 매장은 매년 5% 이상의 성장률을 기록하고 있으며, 이는 브랜드 경험 강화와 고객 충성도 증가에 기여하고 있습니다.',
#    'GrowthDrivers': ['브랜드 경험 강화', '운영 효율성 향상'],
#    'ForecastBox': '2025년까지 직영 매장 시장은 8% 성장 예상',
#    'BenchmarkComparison': {'description': '직영 매장 vs 파트너 매장 성장률 비교',
#     'table': [['연도', '직영 매장', '파트너 매장'],
#      ['2020', '3%', '2%'],
#      ['2021', '4%', '3%'],
#      ['2022', '5%', '3%'],
#      ['2023', '6%', '4%'],
#      ['2024', '7%', '4%'],
#      ['2025', '8%', '5%']]},
#    'OpportunityTags': ['브랜드 경험', '고객 충성도']}},
#  'industry_drivers_challenges': {'slide_description': '산업 내 성장 요인과 저해 요인을 대조해 전략 방향 설정의 기초로 삼습니다.',
#   'description': '리테일 산업은 기술 혁신과 고객 경험 강화가 주요 성장 동인으로 작용하고 있습니다. 그러나 높은 운영 비용과 경쟁 심화는 주요 도전 과제로 남아 있습니다. 이러한 요소들을 고려하여 삼성전자의 직영 매장 전략을 수립해야 합니다.',
#   'elements': {'Title': '리테일 산업의 성장 동인 및 도전 과제',
#    'MiddleText': '산업 변화 요약 및 전략적 시사점',
#    'DriversList': ['기술 혁신', '고객 경험 강화'],
#    'ChallengesList': ['높은 운영 비용', '경쟁 심화'],
#    'DetailComments': '기술 혁신은 고객 경험을 강화하는 데 중요한 역할을 하며, 이는 직영 매장의 경쟁력을 높이는 데 기여합니다. 반면, 높은 운영 비용은 수익성을 저해할 수 있는 요소로, 효율적인 운영 전략이 필요합니다.',
#    'StrategicImplicationsBox': '기술 혁신을 통한 고객 경험 강화와 운영 비용 절감 전략 필요',
#    'QuoteOrDataSupport': '고객 경험 강화는 매출 증가에 직접적인 영향을 미칩니다. (Forrester, 2023)'}},
#  'competitive_benchmarking': {'slide_description': '경쟁사 대비 자사의 상대적 위치와 우위를 정량적·정성적으로 설명합니다.',
#   'description': '삼성전자는 직영 매장 운영에서 경쟁사 대비 차별화된 고객 경험과 운영 효율성을 제공할 수 있는 강점을 가지고 있습니다. 이는 브랜드 충성도를 높이고 시장 내 경쟁력을 강화하는 데 기여할 것입니다.',
#   'elements': {'Title': '경쟁사 대비 삼성전자의 차별화된 강점',
#    'MiddleText': '경쟁 포지셔닝 요약',
#    'TableMain': {'description': '핵심 비교 지표',
#     'table_type': '하이라이트 테이블',
#     'highlight_column': '삼성전자 기준',
#     'data_table': [['항목', '삼성전자', '경쟁사(애플)', '경쟁사(아마존)'],
#      ['고객 경험', '우수', '우수', '보통'],
#      ['운영 효율성', '높음', '보통', '높음']]},
#    'BenchmarkTable': {'description': '세부 항목 비교',
#     'table_type': 'Matrix 테이블',
#     'format': '행: 기업 / 열: 항목',
#     'data_table': [['기업', '고객 경험', '운영 효율성', '기술 혁신'],
#      ['삼성전자', '우수', '높음', '높음'],
#      ['애플', '우수', '보통', '높음'],
#      ['아마존', '보통', '높음', '보통']]},
#    'CompetitiveInsights': '삼성전자는 고객 경험과 운영 효율성에서 경쟁 우위를 가지고 있으며, 이는 브랜드 충성도와 시장 내 경쟁력을 강화하는 데 기여합니다.',
#    'TextBottom': '삼성전자의 차별화된 고객 경험과 운영 효율성은 시장 내 경쟁력을 강화합니다.',
#    'DifferentiationBox': '삼성전자의 차별화 요소: 고객 경험 강화, 운영 효율성',
#    'CustomerPerception': '삼성전자는 고객 경험에서 높은 만족도를 기록하고 있습니다. (NPS: 75)'}},
#  'swot_analysis': {'slide_description': '내부·외부 환경 분석을 통해 전략적 포지션을 진단하고 방향성을 제시합니다.',
#   'description': '삼성전자의 직영 매장 운영은 강력한 브랜드와 기술 혁신을 통해 기회를 극대화할 수 있습니다. 그러나 높은 운영 비용과 경쟁 심화는 주의해야 할 위협 요소입니다. 이를 고려하여 전략적 방향성을 설정해야 합니다.',
#   'elements': {'Title': '삼성전자 직영 매장 운영 SWOT 분석',
#    'MiddleText': 'SWOT 분석 요약',
#    'SWOT-S': ['강력한 브랜드', '기술 혁신'],
#    'SWOT-W': ['높은 운영 비용', '리테일 경험 부족'],
#    'SWOT-O': ['리테일 시장 성장', '고객 경험 강화'],
#    'SWOT-T': ['경쟁 심화', '경제 불확실성'],
#    'NarrativeSummary': '삼성전자는 강력한 브랜드와 기술 혁신을 통해 리테일 시장에서의 기회를 극대화할 수 있습니다. 그러나 높은 운영 비용과 경쟁 심화는 주의해야 할 위협 요소입니다.',
#    'TOWSMatrix': {'description': 'SWOT 기반 전략 매트릭스',
#     'table': [['전략', '내용'],
#      ['SO 전략', '기술 혁신을 통한 고객 경험 강화'],
#      ['ST 전략', '브랜드 강화를 통한 경쟁 우위 확보'],
#      ['WO 전략', '운영 비용 절감을 통한 수익성 개선'],
#      ['WT 전략', '리테일 경험 부족 보완을 위한 파트너십 강화']]},
#    'ImpactAssessmentTable': {'description': '각 요소의 영향도 및 긴급도 평가',
#     'table': [['요소', '영향도', '긴급도'],
#      ['강력한 브랜드', 'High', 'Medium'],
#      ['기술 혁신', 'High', 'High'],
#      ['높은 운영 비용', 'High', 'High'],
#      ['리테일 경험 부족', 'Medium', 'High']]}}},
#  'technical_specifications': {'slide_description': '제안 솔루션의 기술적 구조, 사용 기술, 플랫폼 등을 상세히 설명합니다.',
#   'description': '삼성전자의 직영 매장 운영을 위한 기술적 솔루션은 최신 기술 스택과 플랫폼을 활용하여 운영 효율성을 극대화하고 고객 경험을 강화합니다. 이는 글로벌 표준화된 운영 모델을 지원합니다.',
#   'elements': {'Title': '직영 매장 운영 기술 사양',
#    'MiddleText': '기술 사양 요약',
#    'TechStackDiagram': {'description': '기술 스택 구조도',
#     'visual_type': 'Layer 구조도',
#     'layers': ['Front-End: React.js',
#      'Back-End: Node.js',
#      'Database: MongoDB',
#      'Cloud: AWS']},
#    'SystemCompatibility': '모든 주요 브라우저 및 모바일 플랫폼과 호환',
#    'SecurityFeatures': 'RBAC 기반 접근 통제, 데이터 암호화 저장',
#    'PerformanceMetrics': '응답 시간 < 200ms, 가용성 99.9%',
#    'IntegrationPoints': 'ERP, CRM, Open API 연동',
#    'TechRiskMitigation': '정기적인 보안 점검 및 모니터링',
#    'VersioningPolicy': '버전 관리 정책 및 릴리즈 주기: 매월 업데이트'}},
#  'service_operation_model': {'slide_description': '서비스 운영 및 유지보수 체계를 설명하여 안정성 및 지속 가능성을 강조합니다.',
#   'description': '삼성전자의 직영 매장 운영은 체계적인 서비스 운영 모델을 통해 안정성과 지속 가능성을 보장합니다. 이는 고객 경험을 지속적으로 개선하고 운영 효율성을 극대화하는 데 기여합니다.',
#   'elements': {'Title': '서비스 운영 및 유지보수 모델',
#    'MiddleText': '운영 모델 요약',
#    'OperationOrgChart': {'description': '운영 조직도',
#     'chart_type': 'Org Chart',
#     'roles': ['운영 관리자', '기술 지원', '고객 서비스']},
#    'MaintenancePlan': '정기점검 및 유지보수 계획: 월 1회',
#    'SupportChannels': '24/7 지원 채널: 전화, 이메일, 채팅',
#    'CustomerFeedbackLoop': '고객 피드백 수집 및 반영 절차: 매월',
#    'MonitoringTools': 'Grafana, Slack Alert 사용'}},
#  'compliance_and_governance': {'slide_description': '법적/정책적 준수 사항 및 거버넌스 체계를 설명합니다.',
#   'description': '삼성전자의 직영 매장 운영은 법적/정책적 준수 사항을 철저히 지키며, 체계적인 거버넌스 체계를 통해 운영의 투명성과 신뢰성을 보장합니다.',
#   'elements': {'Title': '컴플라이언스 및 거버넌스 체계',
#    'MiddleText': '컴플라이언스 및 거버넌스 요약',
#    'ComplianceList': ['GDPR 준수', 'CCPA 준수', 'PCI DSS 준수'],
#    'PolicyDiagram': {'description': '보안/정책 흐름도',
#     'visual_type': 'Flowchart',
#     'steps': ['데이터 수집', '데이터 처리', '데이터 저장', '데이터 삭제']},
#    'DataProtectionMeasures': '데이터 보호 및 접근제어 조치: 암호화, RBAC',
#    'AuditAndMonitoring': '정기 감사 및 모니터링 체계: 분기별',
#    'RiskResponseMatrix': {'description': '위협/리스크 발생 시 대응 전략 매트릭스',
#     'table': [['위협', '대응', '복구'], ['데이터 유출', '즉각 대응', '데이터 복구']]},
#    'GovernanceRoles': {'description': '거버넌스 참여 부서 및 R&R 요약 테이블',
#     'table': [['부서', '역할'], ['IT', '보안 관리'], ['법무', '정책 준수']]},
#    'RealTimeMonitoringTools': 'SIEM, DLP 활용 중'}},
#  'client_case_references': {'slide_description': '과거 수행한 유사 프로젝트 사례를 통해 신뢰성과 경험을 강조합니다.',
#   'description': 'EY 컨설팅은 다양한 글로벌 리테일 프로젝트를 성공적으로 수행한 경험을 바탕으로 삼성전자의 직영 매장 운영을 지원할 것입니다. 이는 고객의 신뢰를 높이고 프로젝트의 성공 가능성을 극대화합니다.',
#   'elements': {'Title': '유사 프로젝트 사례',
#    'MiddleText': 'EY 컨설팅의 리테일 프로젝트 수행 경험',
#    'CaseList': [{'고객사': '글로벌 리테일 기업 A',
#      '수행 내용': '직영 매장 운영 효율화',
#      '성과': '운영 비용 15% 절감'},
#     {'고객사': '글로벌 리테일 기업 B', '수행 내용': '고객 경험 강화 프로젝트', '성과': '고객 만족도 20% 증가'}],
#    'VisualHighlights': '대표 사례 이미지',
#    'SuccessIndicators': '주요 성과 지표: 비용 절감, 고객 만족도 증가',
#    'ClientTestimonials': "고객사의 평가: 'EY 컨설팅의 전문성과 경험에 깊은 인상을 받았습니다.'",
#    'IndustryDiversityGraph': {'description': '수행 경험 산업군 분포',
#     'chart_type': 'Donut Chart',
#     'data': [['리테일', '50%'], ['금융', '30%'], ['제조', '20%']]},
#    'CaseImpactSummary': '각 사례의 전략적 효과: 고객 만족도 증가, 운영 효율성 향상'}},
#  'solution_overview': {'slide_description': '제안 솔루션의 핵심 가치와 구조를 시각화하고 간명하게 전달합니다.',
#   'description': 'EY 컨설팅의 제안 솔루션은 삼성전자의 직영 매장 운영을 혁신적으로 개선할 수 있는 핵심 가치를 제공합니다. 이는 비용 절감, 고객 경험 개선, 운영 효율성 향상을 통해 삼성전자의 리테일 전략을 지원합니다.',
#   'elements': {'Title': '제안 솔루션 개요',
#    'ValuePropositionBox': {'description': '고객에게 제공되는 3대 핵심 가치',
#     'format': ['비용 절감', '고객 경험 개선', '운영 효율성 향상']},
#    'SolutionCategoryTag': '컨설팅',
#    'SimpleDiagram': {'description': 'End-to-End 흐름 시각화',
#     'visual_type': 'Linear',
#     'steps': ['분석', '제안', '실행']},
#    'ArchitectureDiagram': {'description': '기술/기능 구조 시각화',
#     'visual_type': 'Block Diagram',
#     'blocks': ['데이터 수집', 'AI 분석', '리포팅']},
#    'KeyModules': {'description': '주요 모듈 또는 기능 구성 요소 리스트',
#     'format': [{'Module': 'Data Collector', 'Function': '실시간 데이터 수집'},
#      {'Module': 'AI Analyzer', 'Function': '패턴 분석 및 이상 탐지'},
#      {'Module': 'Dashboard', 'Function': '시각화 및 리포팅'}]},
#    'FlexibleIntegrationPoints': {'description': '다양한 외부 시스템과 연동 가능한 인터페이스 또는 API 설명',
#     'examples': ['ERP', 'CRM', 'Open API', '클라우드 스토리지']},
#    'ScalabilityAndSecurity': {'description': '확장성 및 보안 체계 설명',
#     'points': ['모듈 확장 가능 구조', 'RBAC 기반 접근 통제', '암호화 저장']}}},
#  'use_case_scenarios': {'slide_description': '솔루션이 실제로 어떻게 작동하고 활용될 수 있는지를 시나리오 기반으로 보여줍니다.',
#   'description': '삼성전자의 직영 매장 운영 솔루션은 다양한 시나리오에서 고객 경험을 개선하고 운영 효율성을 높이는 데 기여합니다. 이를 통해 삼성전자의 리테일 전략을 효과적으로 지원합니다.',
#   'elements': {'Title': '솔루션 활용 시나리오',
#    'MiddleText': '시나리오 요약',
#    'ScenarioDiagram': {'description': '워크플로우 또는 사용자 여정 흐름도',
#     'visual_type': '사용자 Journey Map',
#     'steps': ['고객 요청', '시스템 분석', '자동 처리', '결과 제공']},
#    'NarrativeCases': {'description': '시나리오 2~3개 구성',
#     'format': [{'Title': '고객 VOC 자동 처리',
#       'Before': '수작업으로 2일 소요',
#       'After': '자동 분류 및 1시간 내 응답'},
#      {'Title': '인증 시스템 통합',
#       'Before': '이중 로그인 발생',
#       'After': 'SSO 기반 사용자 편의성 향상'}]},
#    'PersonaIcons': '사용자 유형별 아이콘 및 활용 방식 요약',
#    'ExpectedOutcomes': '각 시나리오별 기대 효과: 시간 단축, 오류 감소',
#    'ProcessExceptionHandling': '예외 상황 처리 플로우: 에러 발생 시 대응 흐름'}},
#  'strategic_recommendations': {'slide_description': '고객을 위한 전략적 방향성과 구체 실행안, 우선순위를 제시합니다.',
#   'description': '삼성전자의 직영 매장 운영을 위한 전략적 방향은 고객 경험 강화와 운영 효율성 향상에 중점을 두어야 합니다. 이를 통해 리테일 시장 내 경쟁력을 강화할 수 있습니다.',
#   'elements': {'Title': '전략적 방향 및 실행안',
#    'MiddleText': '전략 방향 요약',
#    'BulletPoints': ['고객 경험 강화', '운영 효율성 향상', '글로벌 표준화'],
#    'PriorityMap': {'description': '우선순위 매트릭스',
#     'matrix': [['우선순위', '전략'],
#      ['높음', '고객 경험 강화'],
#      ['중간', '운영 효율성 향상'],
#      ['낮음', '글로벌 표준화']]},
#    'StrategicThemes': '전략을 묶는 키 테마: 자동화, 통합, 사용자 중심',
#    'ActionRoadmap': '각 전략별 실행 계획 한 줄 요약',
#    'ClientTailoredValue': "고객 특성 반영 전략 가치 명시: '공공기관의 규제 대응에 특화'"}},
#  'implementation_plan': {'slide_description': '전략 실행을 위한 단계별 로드맵을 구체적으로 설명합니다.',
#   'description': '삼성전자의 직영 매장 운영 전략을 실행하기 위한 단계별 로드맵은 명확한 목표와 일정에 따라 진행됩니다. 이는 프로젝트의 성공적인 완료를 보장합니다.',
#   'elements': {'Title': '전략 실행 로드맵',
#    'MiddleText': '실행 로드맵 핵심 요약',
#    'TimelineMain': {'description': '전체 일정 요약',
#     'period': '6개월',
#     'visual_type': 'Phase Timeline'},
#    'Phases': {'description': '각 단계 명칭, 기간, 주요 작업 정리',
#     'format': [{'Phase': '1단계: 기획/설계',
#       'Duration': '~2개월',
#       'Details': '요구사항 정의 및 상세 설계'},
#      {'Phase': '2단계: 구축/테스트', 'Duration': '~3개월', 'Details': '솔루션 개발, 검증'},
#      {'Phase': '3단계: 운영이관',
#       'Duration': '~1개월',
#       'Details': '고객 교육 및 운영 매뉴얼 전달'}]},
#    'TextBottom': '주요 리스크 및 대응 방안, 기술/인력 관련 고려 사항',
#    'ImplementationTeam': {'description': '각 단계별 역할 및 인력 투입 계획',
#     'table_format': [['단계', '역할', '투입 인원'],
#      ['1단계', 'PM', '1'],
#      ['2단계', '개발자', '3']]},
#    'MilestoneIcons': '각 주요 이벤트에 대한 시각 아이콘',
#    'ClientCollaborationPoints': '고객과의 협업 시점 명시',
#    'SuccessCriteria': '각 단계별 완료 기준 또는 KPI 정의'}},
#  'timeline_milestones': {'slide_description': '전체 일정에서의 주요 마일스톤을 시각화하여 이해도를 높입니다.',
#   'description': '삼성전자의 직영 매장 운영 프로젝트의 주요 마일스톤을 시각화하여 프로젝트 진행 상황을 명확히 이해할 수 있도록 합니다.',
#   'elements': {'Title': '프로젝트 일정 및 마일스톤',
#    'MiddleText': '일정 요약 및 주요 포인트',
#    'GanttChart': {'description': '기간별 주요 활동과 마일스톤 도식화',
#     'chart_type': 'Gantt',
#     'milestones': [{'Date': '2025.07', 'Label': 'Kick-off'},
#      {'Date': '2025.08', 'Label': '1차 개발 완료'},
#      {'Date': '2025.10', 'Label': '통합 테스트 시작'},
#      {'Date': '2025.12', 'Label': '최종 이관'}]},
#    'MilestoneIcons': '각 마일스톤에 대한 시각 아이콘',
#    'DependencyNote': '단계 간 종속 관계 또는 병렬 처리 여부 요약',
#    'ClientCheckpoints': '고객 승인/참여 포인트 명시'}},
#  'risk_management_plan': {'slide_description': '예상되는 리스크를 식별하고 이에 대한 대응 전략을 제시합니다.',
#   'description': '삼성전자의 직영 매장 운영 프로젝트에서 예상되는 리스크를 식별하고, 이에 대한 대응 전략을 제시하여 프로젝트의 성공적인 완료를 보장합니다.',
#   'elements': {'Title': '리스크 관리 계획',
#    'MiddleText': '리스크 관리 개요',
#    'RiskTable': {'description': '리스크 목록',
#     'table': [['내용', '가능성', '영향도'],
#      ['프로젝트 일정 지연', '중', '높음'],
#      ['예산 초과', '낮음', '중'],
#      ['기술적 문제', '중', '높음']]},
#    'MitigationStrategy': '완화 전략 항목: 일정 관리 강화, 예산 모니터링, 기술 지원 강화'}},
#  'expected_benefits': {'slide_description': '제안서 실행 시 고객이 얻게 될 주요 기대 효과를 정성·정량적으로 표현합니다.',
#   'description': '삼성전자의 직영 매장 운영 프로젝트를 통해 고객은 운영 효율성 향상, 고객 경험 개선, 비용 절감 등의 주요 기대 효과를 얻을 수 있습니다.',
#   'elements': {'Title': '기대 효과',
#    'MiddleText': '핵심 기대 효과 요약',
#    'BulletPoints': {'description': '정성적 효과 정리',
#     'examples': ['운영 프로세스 간소화 및 자동화', '직원 업무 효율 증대', '고객 만족도 향상']},
#    'KPIProjection': {'description': '성과 지표 기반 기대 성과',
#     'chart_type': 'Line',
#     'data': [['항목', '현재', '도입 후'],
#      ['처리 시간', '5일', '2일'],
#      ['운영 비용', '100%', '80%']]},
#    'TangibleVsIntangible': '정량 vs 정성 효과 분류 테이블',
#    'ROIIndicator': 'ROI, Payback 기간 등 주요 재무적 효과 요약',
#    'ClientQuoteBox': '고객이 공감할 수 있는 기대 효과 강조 인용문'}},
#  'investment_budget_estimation': {'slide_description': '전체 예산과 각 항목별 비용을 상세히 제시하여 투자 가시성을 제공합니다.',
#   'description': '삼성전자의 직영 매장 운영 프로젝트에 필요한 전체 예산과 각 항목별 비용을 상세히 제시하여 투자 가시성을 제공합니다.',
#   'elements': {'Title': '투자 및 예산 추정',
#    'MiddleText': '투자 요약',
#    'BudgetTable': {'description': '총 예산 테이블',
#     'table': [['항목', '예산'],
#      ['인력 비용', '$500,000'],
#      ['기술 비용', '$300,000'],
#      ['운영 비용', '$200,000']]},
#    'CostBreakdown': '비용 항목별 상세 내용: 인력, 기술, 운영'}},
#  'team_introduction': {'slide_description': '수행팀의 전문성과 역할 분담을 보여줘 신뢰도를 높입니다.',
#   'description': 'EY 컨설팅의 전문적인 수행팀은 삼성전자의 직영 매장 운영 프로젝트를 성공적으로 이끌어 갈 것입니다. 각 팀원은 풍부한 경험과 전문성을 바탕으로 프로젝트의 성공을 보장합니다.',
#   'elements': {'Title': '수행팀 소개',
#    'MiddleText': '팀 구성 및 핵심 인력 요약',
#    'MemberList': [{'이름': '김철수', '역할': '프로젝트 매니저', '경력': '10년'},
#     {'이름': '이영희', '역할': '리테일 전문가', '경력': '8년'},
#     {'이름': '박민수', '역할': '기술 전문가', '경력': '7년'}],
#    'TeamOrgChart': {'description': '팀 조직도',
#     'chart_type': 'Org Chart',
#     'roles': ['프로젝트 매니저', '리테일 전문가', '기술 전문가']}}},
#  'why_us_differentiation': {'slide_description': '자사만의 차별성과 강점을 강조하여 경쟁사 대비 우위를 설득합니다.',
#   'description': 'EY 컨설팅은 업계 최고 수준의 기술 인력과 구축 경험을 보유하고 있으며, 공공/금융 분야에서 다수의 실증 사례를 가지고 있습니다. 이는 삼성전자의 직영 매장 운영 프로젝트에서 경쟁사 대비 우위를 제공합니다.',
#   'elements': {'Title': 'EY 컨설팅의 차별화된 강점',
#    'MiddleText': '자사 강점 요약',
#    'BulletPoints': {'description': '차별화된 요소 요약 리스트',
#     'examples': ['업계 최고 수준의 기술 인력 및 구축 경험',
#      '공공/금융 분야 다수의 실증 사례',
#      '전담 PM 배정 및 신속한 커뮤니케이션 구조',
#      'End-to-End 서비스 제공 (컨설팅 ~ 운영까지)']},
#    'ComparisonTable': {'description': '자사 vs 경쟁사 비교',
#     'table_format': [['항목', '자사', '경쟁사'],
#      ['경험', '10건 이상 유사 구축', '2~3건 제한적'],
#      ['대응 속도', '24시간 이내 피드백', '72시간 이상']]}}},
#  'closing_summary': {'slide_description': '전체 제안을 요약하며 고객에게 남기고 싶은 핵심 메시지를 강조합니다.',
#   'description': 'EY 컨설팅은 삼성전자의 직영 매장 운영 프로젝트를 성공적으로 이끌어 갈 수 있는 최적의 파트너입니다. 우리의 전문성과 경험을 바탕으로 삼성전자의 리테일 전략을 지원할 것입니다.',
#   'elements': {'Title': '제안 마무리',
#    'MiddleText': '핵심 요약 문장',
#    'FinalCall': {'description': '마무리 제안 또는 CTA',
#     'options': ['시범 도입 제안', '추가 미팅 요청', 'RFP 연장 논의', '기술 검증(PoC) 요청 등']},
#    'ThankYouVisual': '감사 인사와 함께 신뢰를 전달하는 이미지 또는 문구',
#    'ContactInfoBox': {'description': '담당자 연락처 정보',
#     'info': [{'이름': '박일혜', '이메일': 'ilhye.park@samsung.com', '직책': '프로'},
#      {'이름': '박선연', '이메일': 'sunyeon.park@samsung.com', '직책': '프로'},
#      {'이름': '서범주', '이메일': 'beomjoo.seo@samsung.com', '직책': '프로'},
#      {'이름': '이은지', '이메일': 'eunji81.lee@samsung.com', '직책': '프로'}]},
#    'ReinforcementBanner': '슬라이드 하단에 ‘선택의 이유’를 다시 강조하는 요약 배너'}},
#  'qna': {'slide_description': '질의응답을 위한 충분한 공간과 예상 질문 대응 내용을 구성합니다.',
#   'description': '삼성전자의 직영 매장 운영 프로젝트에 대한 질의응답 시간을 통해 고객의 궁금증을 해소하고, 프로젝트의 성공적인 진행을 위한 신뢰를 구축합니다.',
#   'elements': {'Title': '질의응답',
#    'EmptySpace': 'Q&A 시각적 공간',
#    'AnticipatedQuestions': [{'질문': '프로젝트 일정은 어떻게 되나요?',
#      '답변': '2025년 7월부터 10월까지 진행됩니다.'},
#     {'질문': '운영 비용은 어떻게 관리되나요?', '답변': '효율적인 비용 관리 방안을 통해 예산 내에서 운영됩니다.'},
#     {'질문': '기술적 문제 발생 시 어떻게 대응하나요?',
#      '답변': '정기적인 모니터링과 기술 지원을 통해 문제를 신속히 해결합니다.'}]}},
#  'appendix': {'slide_description': '통계, 기술 스펙, 참고 문헌 등 본문에 넣기 어려운 자료를 정리합니다.',
#   'description': '삼성전자의 직영 매장 운영 프로젝트에 관련된 추가 자료와 통계, 기술 스펙 등을 제공합니다.',
#   'elements': {'Title': '부록',
#    'SupportingDetails': '기술 자료, 통계 인용 등',
#    'Footnotes': '출처, 링크, 각주 등 보충 정보'}}}

# %%
proposal_dict.keys()
# Out:
# dict_keys(['cover_page', 'table_of_contents', 'executive_summary', 'project_understanding', 'client_needs_summary', 'requirement_detail_01', 'requirement_detail_02', 'requirement_detail_03', 'requirement_detail_04', 'market_analysis_market_overview', 'growth_trend_analysis', 'industry_drivers_challenges', 'competitive_benchmarking', 'swot_analysis', 'technical_specifications', 'service_operation_model', 'compliance_and_governance', 'client_case_references', 'solution_overview', 'use_case_scenarios', 'strategic_recommendations', 'implementation_plan', 'timeline_milestones', 'risk_management_plan', 'expected_benefits', 'investment_budget_estimation', 'team_introduction', 'why_us_differentiation', 'closing_summary', 'qna', 'appendix'])

# %% [markdown]
# ### ppt 자동 생성 Test

# %%
pptx_path = "DB/rfp_to_proposal.pptx"
output_path = "DB/proposal/final_ppt/full_generated_proposal_v1.pptx"
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'  # 윈도우의 기본 한글 폰트

# %%
from pathlib import Path
from pptx import Presentation
from pptx.dml.color import RGBColor
import matplotlib.pyplot as plt
from matplotlib import font_manager
from pathlib import Path

# %%
# 📌 한글 폰트 설정 (Windows 전용: Malgun Gothic)
font_path = "C:/Windows/Fonts/malgun.ttf"
if os.path.exists(font_path):
    font_name = font_manager.FontProperties(fname=font_path).get_name()
    plt.rcParams["font.family"] = font_name

# 📌 그래프 또는 테이블 삽입 함수
def insert_graph_or_table(slide, placeholder, graph_data):
    from matplotlib import pyplot as plt

    graph_type = graph_data.get("graph_type", "")
    table_data = graph_data.get("table_data", [])

    chart_dir = Path("./DB/charts")
    chart_dir.mkdir(parents=True, exist_ok=True)
    chart_path = chart_dir / "temp_chart.png"

    if graph_type == "Bar Chart":
        categories = [row[0] for row in table_data[1:]]
        values_raw = [row[1] for row in table_data[1:]]

        def parse_value(v):
            match = re.search(r"[\d.]+", v)
            return float(match.group()) if match else 0.0

        values = [parse_value(v) for v in values_raw]

        fig, ax = plt.subplots()
        ax.bar(categories, values)
        ax.set_title(graph_data.get("data_source", ""))
        fig.tight_layout()

        plt.savefig(chart_path)
        plt.close()

        for shape in slide.shapes:
            if shape.has_text_frame and shape.text.strip() == placeholder:
                left, top, width, height = shape.left, shape.top, shape.width, shape.height
                slide.shapes._spTree.remove(shape._element)
                slide.shapes.add_picture(str(chart_path), left, top, width, height)
                break
    else:
        rows, cols = len(table_data), len(table_data[0])
        for shape in slide.shapes:
            if shape.has_text_frame and shape.text.strip() == placeholder:
                left, top, width, height = shape.left, shape.top, shape.width, shape.height
                slide.shapes._spTree.remove(shape._element)
                table_shape = slide.shapes.add_table(rows, cols, left, top, width, height).table
                for i in range(rows):
                    for j in range(cols):
                        cell = table_shape.cell(i, j)
                        cell.text = table_data[i][j]
                        if i == 0:
                            cell.fill.solid()
                            cell.fill.fore_color.rgb = RGBColor(230, 230, 230)
                break

# 📌 텍스트 삽입 함수
def insert_text(slide, target_text, replacement, bullet=False):
    for shape in slide.shapes:
        if shape.has_text_frame and shape.text.strip() == target_text:
            shape.text_frame.clear()
            if isinstance(replacement, list) or bullet:
                for item in replacement:
                    p = shape.text_frame.add_paragraph()
                    p.text = f"• {item}"
            else:
                shape.text = replacement

# 📌 슬라이드별 내용 삽입 함수
def fill_cover_page(slide, elements):
    insert_text(slide, "Title", elements.get("Title", ""))
    insert_text(slide, "Subtitle", elements.get("Subtitle", ""))
    insert_text(slide, "ProjectDate", elements.get("ProjectDate", ""))
    insert_text(slide, "PreparedBy", elements.get("PreparedBy", ""))
    insert_text(slide, "Log", elements.get("Logo", ""))

def fill_executive_summary(slide, elements):
    insert_text(slide, "Title", elements.get("Title", ""))
    insert_text(slide, "SummaryPoints", elements.get("SummaryPoints", []), bullet=True)
    insert_text(slide, "ClientValue", elements.get("ClientValue", ""))
    insert_text(slide, "GraphLeftdescription", elements.get("GraphLeft", {}).get("description", ""))
    insert_graph_or_table(slide, "GraphLeft", elements.get("GraphLeft", {}))

def fill_project_understanding(slide, elements):
    insert_text(slide, "Title", elements.get("Title", ""))
    insert_text(slide, "MiddleText", elements.get("MiddleText", ""))
    insert_text(slide, "BackgroundIssues", elements.get("BackgroundIssues", []), bullet=True)
    insert_text(slide, "GraphLeftdescription", elements.get("GraphLeft", {}).get("description", ""))
    insert_graph_or_table(slide, "GraphLeft", elements.get("GraphLeft", {}))

def fill_client_needs_summary(slide, elements):
    insert_text(slide, "Title", elements.get("Title", ""))
    insert_text(slide, "MiddleText", elements.get("MiddleText", ""))
    insert_text(slide, "BulletPoints", elements.get("BulletPoints", []), bullet=True)
    insert_text(slide, "GraphLeftdescription", elements.get("GraphLeft", {}).get("description", ""))
    insert_graph_or_table(slide, "GraphLeft", elements.get("GraphLeft", {}))
    insert_graph_or_table(slide, "NeedsMatrix", {"table_data": elements.get("NeedsMatrix", [])})

# ✅ apply_to_ppt 함수: 전체 흐름 실행
def apply_to_ppt(prs: Presentation, proposal_dict: dict):
    for slide in prs.slides:
        for shape in slide.shapes:
            if not shape.has_text_frame:
                continue
            text = shape.text.strip()
            if text == "cover_page":
                fill_cover_page(slide, proposal_dict.get("cover_page", {}).get("elements", {}))
            elif text == "executive_summary":
                fill_executive_summary(slide, proposal_dict.get("executive_summary", {}).get("elements", {}))
            elif text == "project_understanding":
                fill_project_understanding(slide, proposal_dict.get("project_understanding", {}).get("elements", {}))
            elif text == "client_needs_summary":
                fill_client_needs_summary(slide, proposal_dict.get("client_needs_summary", {}).get("elements", {}))

# 🎯 전체 함수 작성 완료
"✅ 전체 코드 완성: apply_to_ppt(prs, proposal_dict) 로 실행 가능"
# Out:
# '✅ 전체 코드 완성: apply_to_ppt(prs, proposal_dict) 로 실행 가능'

# %%
from pptx import Presentation

# 1. 템플릿 PPT 불러오기
prs = Presentation("DB/rfp_to_proposal.pptx")

# 2. proposal_dict 내용 채워서 적용
apply_to_ppt(prs, proposal_dict)

# 3. 결과 저장 (경로 자동 생성 필요 시 os.makedirs 사용)
output_path = "DB/proposal/final_result/full_generated_proposal_v1.pptx"
os.makedirs(Path(output_path).parent, exist_ok=True)
prs.save(output_path)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[59], line 7
#       4 prs = Presentation("DB/rfp_to_proposal.pptx")
#       6 # 2. proposal_dict 내용 채워서 적용
# ----> 7 apply_to_ppt(prs, proposal_dict)
#       9 # 3. 결과 저장 (경로 자동 생성 필요 시 os.makedirs 사용)
#      10 output_path = "DB/proposal/final_result/full_generated_proposal_v1.pptx"
#
# Cell In[58], line 110, in apply_to_ppt(prs, proposal_dict)
#     108     fill_cover_page(slide, proposal_dict.get("cover_page", {}).get("elements", {}))
#     109 elif text == "executive_summary":
# --> 110     fill_executive_summary(slide, proposal_dict.get("executive_summary", {}).get("elements", {}))
#     111 elif text == "project_understanding":
#     112     fill_project_understanding(slide, proposal_dict.get("project_understanding", {}).get("elements", {}))
#
# Cell In[58], line 83, in fill_executive_summary(slide, elements)
#      81 insert_text(slide, "ClientValue", elements.get("ClientValue", ""))
#      82 insert_text(slide, "GraphLeftdescription", elements.get("GraphLeft", {}).get("description", ""))
# ---> 83 insert_graph_or_table(slide, "GraphLeft", elements.get("GraphLeft", {}))
#
# Cell In[58], line 43, in insert_graph_or_table(slide, placeholder, graph_data)
#      41             break
#      42 else:
# ---> 43     rows, cols = len(table_data), len(table_data[0])
#      44     for shape in slide.shapes:
#      45         if shape.has_text_frame and shape.text.strip() == placeholder:
#
# IndexError: list index out of range
